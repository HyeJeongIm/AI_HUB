# %% [markdown]
# <a href="https://colab.research.google.com/github/HyeJeongIm/AI_HUB_yangjae/blob/main/week01/image/0707_Image_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
img = Image.open("/content/gdrive/MyDrive/Colab Notebooks/양재 AI/0707/img/test_img.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=934x1216 at 0x7F81A1804850>

# %%
img.size
# Out:
# (934, 1216)

# %%
img.format
# Out:
# 'PNG'

# %%
img.mode
# Out:
# 'RGBA'

# %%
img_resized = img.resize(((200, 200 )))
img_resized.size
# Out:
# (200, 200)

# %%
img_resized
# Out:
# <PIL.Image.Image image mode=RGBA size=200x200 at 0x7F819FF91A10>

# %%
# 이미지 자르기

# %%
img_cropped = img.crop((300,300, 600, 600))
print(img_cropped.size)
new_img = img_cropped
new_img
# Out:
# (300, 300)
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F819FF58190>

# %%
# 이미지를 흑백으로 바꾸기 
# convert("L")

# %%
img_gray = img_cropped.convert("L")
img_gray
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x7F819FFA5F10>

# %%
# 이미지 회전시키기 
# rotate()

# %%
img_rotated = img_cropped.rotate(45)
img_rotated
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F81A180BD50>

# %%
print(img_rotated.size)
# Out:
# (300, 300)

# %%
# 이미지에 필터 적용하기

# %%
from PIL import ImageFilter

# %%
new_img
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F819FF58190>

# %%
img_blur = new_img.filter(ImageFilter.BLUR)
img_blur
# Out:
# <PIL.Image.Image image mode=RGBA size=300x300 at 0x7F81A181C790>

# %%
# iamge -> numpy array

# %%
import numpy as np 

num_img = np.array(new_img)

# %%
type(num_img)
# Out:
# numpy.ndarray

# %%
type(new_img)
# Out:
# PIL.Image.Image

# %%
np.shape(num_img)
# (height, width, channel) 형태 3차원 배열의 사이즈가 출력됩니다.
# Out:
# (300, 300, 4)

# %%
new_img.size
# (width, height)
# Out:
# (300, 300)

# %%
# 이미지 저장하기 
new_img.save("/content/gdrive/MyDrive/Colab Notebooks/양재 AI/0707/img/final_img.png")
